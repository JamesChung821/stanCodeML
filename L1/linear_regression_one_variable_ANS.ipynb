# %%
#  File: linear_regression_one_varialbe
#  ----------------------------
#  This file shows student the fundamental concepts of 
#  machine learing:
#      - loss function
#      - cost function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the L2 loss which is 
# ----------------------------------------
# [sum of (theta*x_i - y_i)^2] / (2*m)
# ----------------------------------------
# of data (x, y) to the line y = theta*x
# 
# x_list: list, containing 21 data points
# y_list: list, containing 21 data points
# theta: float, slop of the line
# return: float, the sum over all L2 loss of data points

def cost_function(theta, x, y):
    return sum((theta*x[i]-y[i])**2 for i in range(len(x)))/(2*len(x))

# %%
# You should see 2.3333333333333335
print(cost_function(1.1, [0, 0, 0], [1, 2, 3]))
# Out:
# 2.3333333333333335

# %%
# This function returns the partial derivative of L2 loss function
# relative to theta: 
# --------------------------------------
# [sum of (theta*x_i - y_i) * (x_i)] / m
# --------------------------------------
# x_list: list, containing 21 data points
# y_list: list, containing 21 data points
# theta: float, slop of the line
# return: flaot, the sum over dJ_dtheta over all data points

def dJ_dtheta(theta, x, y):
    return sum((theta*x[i]-y[i])*x[i] for i in range(len(x)))/len(x)

# %%
# You should see 0.46666666666666706
print(dJ_dtheta(1.1, [1, 2, 3], [1, 2, 3]))
# Out:
# 0.46666666666666706

# %%
# ---------- DO NOT EDIT THE CODE BELOW THIS LINE ---------- #

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0, 30)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = 0.5

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01

# %%
# ---------- Training process ---------- #
# ---- 11 iterations over all data ----- #

# %%
theta_history = []
cost_history = []
for i in range(1100):
    theta_history.append(theta)
    cost = cost_function(theta, x, y)
    cost_history.append(cost)
    
    # Gradient Descent
    theta = theta - alpha * dJ_dtheta(theta, x, y)

# %%
# ---------- Theta changes during training process ---------- #

# %%
print(cost_history)
# Out:
# [11.75230332767381, 6.900440081405466, 5.539857933100084, 5.15831713355033, 5.051323680856294, 5.021320077223599, 5.012906326584838, 5.010546903340956, 5.009885262857085, 5.009699722542932, 5.009647692461617, 5.009633101943249, 5.009629010401955, 5.00962786303284, 5.009627541282235, 5.009627451055427, 5.009627425753605, 5.00962741865835, 5.009627416668665, 5.009627416110708, 5.0096274159542435, 5.009627415910367, 5.009627415898063, 5.009627415894613, 5.009627415893644, 5.009627415893373, 5.009627415893296, 5.009627415893275, 5.00962741589327, 5.009627415893267, 5.009627415893267, 5.0096274158932665, 5.0096274158932665, 5.009627415893268, 5.009627415893267, 5.009627415893267, 5.009627415893269, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893269, 5.0096274158932665, 5.009627415893267, 5.009627415893268, 5.009627415893269, 5.009627415893268, 5.009627415893267, 5.0096274158932665, 5.009627415893268, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893267, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627415893268, 5.009627 ...

# %%
theta = theta_history[0]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("0 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.5

# %%
theta = theta_history[1]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.7518762609633334

# %%
theta = theta_history[2]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.8852576838890467

# %%
theta = theta_history[3]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.9558900011770894

# %%
theta = theta_history[4]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.993293442646276

# %%
theta = theta_history[5]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.013100486892518

# %%
theta = theta_history[-1]

print(f'theta: {theta}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("10 iterations", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.0353959032099576

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(cost_history)))
plot_y = cost_history
plt.plot(plot_x, plot_y)
plt.title("Costs over iterations", color = 'blue', fontdict = {'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Costs over iterations')

# %%
print('####################################################')
print(f'###### Final theta learned: {theta_history[-1]} ######')
print('####################################################')
# Out:
# ####################################################
# ###### Final theta learned: 1.0353959032099576 ######
# ####################################################
